# %% [markdown]
# # AI Workflow Audit — FL-01 (Setup)
#
# **Phase:** Setup | **Estimated hours:** 4
#
# **Why it matters:** You cannot improve a workflow you have never mapped. Knowing where AI helps, where it wastes your time, and where it should never be trusted is the core fluency skill; everything else builds on this audit.
#
# **Student:** 4th Year BS Data Science
# **Context:** ML internship, research papers, undergraduate thesis, and personal skill-building.

# %% [markdown]
# ---
# ## Task 1: Recurring Task Audit (10–15 tasks)
#
# Classify each task as one of:
# - **Just Me** — I do this myself, no AI involved.
# - **Collaborate with AI** — I work interactively with AI, but I make the final decisions.
# - **Delegate to AI with Review** — AI does the first pass, I review/verify before using it.
# - **Fully Automate** — AI runs with no manual review needed.

# %% [markdown]
# | # | Recurring Task | Classification | Rationale |
# |---|-----------------|-----------------|-----------|
# | 1 | Taking lecture and meeting notes | Just Me | I retain information better by writing notes myself, although AI can help organize them afterward. |
# | 2 | Writing social media captions | Collaborate with AI | AI helps generate ideas and improve wording, but I decide the final message and tone. |
# | 3 | Grammar and writing improvement | Delegate to AI with Review | AI quickly corrects grammar and improves clarity, but I review everything before submitting. |
# | 4 | Replying to important emails | Just Me | Professional emails represent me personally, so I prefer to write and review them myself. |
# | 5 | Drafting emails from scratch | Collaborate with AI | AI helps structure the email, but I edit details to match the situation and recipient. |
# | 6 | Creating study reviewers and summaries | Collaborate with AI | AI speeds up summarization while I verify the important concepts before studying. |
# | 7 | Recording internship hours and accomplishments | Just Me | Time records must accurately reflect my actual work and cannot be delegated. |
# | 8 | Writing Python code for assignments and projects | Collaborate with AI | AI helps explain concepts, debug code, and suggest improvements, but I implement and test everything myself. |
# | 9 | Writing research papers and project reports | Collaborate with AI | AI assists with organization, editing, and readability, while I provide the analysis and conclusions. |
# | 10 | Thesis implementation and debugging | Collaborate with AI | AI helps troubleshoot technical issues, but I design, test, and validate the implementation myself. |
# | 11 | Thesis manuscript writing | Collaborate with AI | AI improves structure and writing quality, but I ensure the content accurately reflects my research. |
# | 12 | Organizing datasets before analysis | Delegate to AI with Review | AI can recommend cleaning steps and identify inconsistencies, but I verify the final dataset before analysis. |
# | 13 | Creating data visualizations | Collaborate with AI | AI suggests visualization methods and code, while I interpret the results and choose the final presentation. |
# | 14 | GitHub documentation and README updates | Delegate to AI with Review | AI drafts documentation efficiently, but I verify that it accurately describes my project. |

# %% [markdown]
# ### Quick reflection
#
# *(Optional — fill in after reviewing the table above)*
#
# - Which category has the most tasks, and what does that say about your current AI habits?
# - Is there any task marked **Just Me** that you're avoiding delegating out of habit rather than necessity?
# - Is there any task marked **Collaborate/Delegate** where you should actually be doing more yourself to protect your learning?

# %% [markdown]
# ---
# ## Task 2: Set Up Your Free AI Toolkit
#
# Checklist — check off as you complete each step:
#
# - [ ] Created/verified a **Claude.ai** account
# - [ ] Created/verified a **ChatGPT** account
# - [ ] Created/verified an **Anthropic Academy** account
# - [ ] Enrolled in **AI Fluency: Framework & Foundations**
# - [ ] Completed **at least the first module** of the course

# %% [markdown]
# ### 📸 Screenshot: Toolkit Accounts / Course Enrollment
#
# *(Add your screenshots here — e.g., Claude account, ChatGPT account, Anthropic Academy enrollment page, and first module completion.)*
#
# <!-- Drag and drop your image(s) into this cell, or use: ![description](attachment:filename.png) -->

# %% [markdown]
# ---
# ## Task 3: Create a Claude Project with Custom Instructions
#
# Set up one Claude Project and define custom instructions covering:
#
# **Who you are:**
# > 4th-year BS Data Science student working on ML projects, research papers, an internship, and an undergraduate thesis. Uses AI to boost productivity while keeping all academic work original.
#
# **Tone preferences:**
# > Clear, concise, professional, and beginner-friendly. Explain technical concepts in simple language first, then add advanced detail. Avoid unnecessary jargon. Keep responses well-structured.
#
# **Current goals:**
# > - Complete the ML internship successfully
# > - Finish the undergraduate thesis
# > - Improve programming and data science skills
# > - Build a strong GitHub portfolio
# > - Produce high-quality academic reports and research papers
# > - Use AI responsibly — increase productivity without compromising learning

# %% [markdown]
# ### 📸 Screenshot: Claude Project Setup
#
# *(Add a screenshot of your created Claude Project and its custom instructions here.)*
#
# <!-- Drag and drop your image(s) into this cell, or use: ![description](attachment:filename.png) -->

# %% [markdown]
# ---
# ## Task 4: Select 3 Audit Tasks to Reuse in FL-02 → FL-04
#
# Pick three tasks from the Task 1 table that you'll continue optimizing in the next phases, and define what **"done well"** looks like for each.

# %% [markdown]
# | Selected Task | Current Classification | What "Done Well" Looks Like |
# |---|---|---|
# | Writing Python code for assignments and projects | Collaborate with AI | Code runs correctly, is well-documented, follows good practices, and I can explain every part of it without relying on AI-generated logic I don't understand. |
# | Writing research papers and project reports | Collaborate with AI | AI only helps with structure, phrasing, and clarity; all analysis, conclusions, and claims are mine and fully verifiable against my own data/results. |
# | Thesis manuscript writing | Collaborate with AI | Final manuscript reads in my own academic voice, accurately reflects my methodology and findings, and passes a plagiarism/originality check with no unverified AI claims. |

# %% [markdown]
# ### 📸 Screenshot: Supporting Evidence (Optional)
#
# *(Add any additional screenshots relevant to Task 4, e.g., examples of AI-assisted vs. self-written work.)*
#
# <!-- Drag and drop your image(s) into this cell, or use: ![description](attachment:filename.png) -->

# %% [markdown]
# ---
# ## ✅ FL-01 Completion Summary
#
# - [ ] Task 1: Recurring task audit completed (10–15 tasks classified)
# - [ ] Task 2: Toolkit set up + first AI Fluency module completed
# - [ ] Task 3: Claude Project created with custom instructions
# - [ ] Task 4: Three reuse tasks selected with "done well" criteria defined
#
# **Next phase:** FL-02
